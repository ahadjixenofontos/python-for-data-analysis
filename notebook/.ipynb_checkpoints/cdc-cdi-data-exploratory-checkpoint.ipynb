# %% [markdown]
# # Python for data analysis workshop
# ## A quick and dirty exploratory analysis of the Chronic Disease Indicators dataset

# %% [markdown]
# Disclaimer: You can check out the pandas, numpy, scipy etc documentation for the various data types that they make available to you and how to work with them. In this workshop, we'll be focusing on the parts of data analysis that may be more difficult to internalize by reading alone.

# %% [markdown]
# I'm interested in the relationship between alcohol consumption and liver disease mortality.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import the Chronic Disease Indicators dataset

# %% [markdown]
# The Chronic Disease Indicators dataset was downloaded from the Centers for Disease Control website.
# A number of readme files in the 'data' directory provide more information on the variables. These are important, take a look!

# %%
# Import the dataset
data = pd.read_csv('../data/U.S._Chronic_Disease_Indicators__CDI_mod.csv', 
                       sep = ',', 
                       dtype={'YearStart' : np.int64,
                              'YearEnd' : np.int64, 
                              'LocationAbbr' : str,
                              'LocationDesc' : str,
                              'DataSource' : str, 
                              'Topic' : str,
                              'Question' : str,
                              'DataValueUnit' : str,
                              'DataValueType' : str,
                              'DataValue' : str,
                              'DataValueAlt' : np.float64,
                              'DataValueFootnoteSymbol' : str,
                              'DataValueFootnote' : str,
                              'LowConfidenceLimit' : np.float64,
                              'HighConfidenceLimit' : np.float64,
                              'StratificationCategory' : str,
                              'Stratification' : str,
                              'GeoLocation'  : str,
                              'LocationID' : np.int64,
                              'TopicID'    : str,
                              'QuestionID'   : str,
                              'DataValueTypeID'    : str,
                              'StratificationCategoryID' : str,
                              'StratificationID' : str
                             })

# %% [markdown]
# ### What variables do we have?

# %% [markdown]
# The first, coarsest look that you can have at the data is to list all the variables that are present.
#
# In Jupyter notebooks, tab completion for both the names of the columns and the public attributes is enabled by default.
#
# **Question:** Is this information enough to know what was measured? Why, or why not?

# %%
isinstance(data, pd.DataFrame)
data.columns
data.index
data.values
data.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# DataValueUnit                 object
# DataValueType                 object
# DataValue                     object
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# GeoLocation                   object
# LocationID                     int64
# TopicID                       object
# QuestionID                    object
# DataValueTypeID               object
# StratificationCategoryID1     object
# StratificationID1             object
# dtype: object

# %% [markdown]
# ### Take a first peek

# %%
data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource    Topic  \
# 0       2013     2013           AK       Alaska      YRBSS  Alcohol
# 1       2013     2013           AL      Alabama      YRBSS  Alcohol
# 2       2013     2013           AR     Arkansas      YRBSS  Alcohol
# 3       2013     2013           AZ      Arizona      YRBSS  Alcohol
# 4       2013     2013           CA   California      YRBSS  Alcohol
#
#                   Question DataValueUnit     DataValueType DataValue  \
# 0  Alcohol use among youth             %  Crude Prevalence      22.5
# 1  Alcohol use among youth             %  Crude Prevalence        35
# 2  Alcohol use among youth             %  Crude Prevalence      36.3
# 3  Alcohol use among youth             %  Crude Prevalence        36
# 4  Alcohol use among youth             %  Crude Prevalence       NaN
#
#          ...         HighConfidenceLimit StratificationCategory1  \
# 0        ...                        26.1                 Overall
# 1        ...                        40.3                 Overall
# 2        ...                        40.4                 Overall
# 3        ...                        40.9                 Overall
# 4        ...                         NaN                 Overall
#
#   Stratification1                                GeoLocation  LocationID  \
# 0         Overall   (64.84507995700051, -147.72205903599973)           2
# 1         Overall    (32.84057112200048, -86.63186076199969)           1
# 2         Overall    (34.74865012400045, -92.27449074299966)           5
# 3         Overall  (34.865970280000454, -111.76381127699972)           4
# 4         Overall   (37.63864012300047, -120.99999953799971)           6
#
#   TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0     ALC     ALC1_1         CrdPrev                    OVERALL
# 1     ALC     ALC1_1         CrdPrev                    OVERALL
# 2     ALC     ALC1_1         CrdPrev                    OVERALL
# 3     ALC     ALC1_1         CrdPrev                    OVERALL
# 4     ALC     ALC1_1         CrdPrev                    OVERALL
#
#   StratificationID1
# 0               OVR
# 1               OVR
# 2               OVR
# 3               OVR
# 4               OVR
#
# [5 rows x 24 columns]

# %% [markdown]
# ## numpy and pandas provide some great functionality for data analysis

# %% [markdown]
# **Question:** What are the primitive data types? Why are they called primitive?
#
# In addition to primitive data types, there are a lot of custom ones, built to make your life easier with respect to a specific problem.
#
# **Question:** What is the key data type that numpy offers beyond the capabilities of the Python Standard Library? Why was this useful?
#
# **Question:** What are the key data types that pandas offers? Why are they useful?
#
# **Question:** What happened when we imported the CDIs .csv dataset?
#
# **Question:** Use the pandas documentation (and/or the method itself!) to figure out what the .describe() method below does. What type of object does it take?

# %%
data.describe()
# Out:
#            YearStart        YearEnd  DataValueAlt  LowConfidenceLimit  \
# count  404155.000000  404155.000000  2.717970e+05       244930.000000
# mean     2012.720899    2012.747735  7.355094e+02           49.968239
# std         1.552934       1.522028  1.807338e+04           83.909972
# min      2001.000000    2001.000000  0.000000e+00            0.000000
# 25%      2011.000000    2011.000000  1.900000e+01           13.000000
# 50%      2013.000000    2013.000000  4.190000e+01           31.400000
# 75%      2014.000000    2014.000000  7.120000e+01           57.600000
# max      2016.000000    2016.000000  3.967333e+06         1293.900000
#
#        HighConfidenceLimit     LocationID
# count        244930.000000  404155.000000
# mean             62.905365      31.004137
# std              96.295604      17.700753
# min               0.000000       1.000000
# 25%              20.200000      17.000000
# 50%              45.900000      30.000000
# 75%              72.300000      45.000000
# max            2088.000000      78.000000

# %%
# Accessing some of the attributes can provide further information about the dataset
data.shape
# Out:
# (160267, 24)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=160267, step=1)

# %% [markdown]
# ## Which years are included in these observations?

# %% [markdown]
# One of the first questions you may ask when you take a peek at the file is "how many years does this dataset span?".
#
# In fact, you can ask the "what are the unique values?" for any of the variables. It wouldn't make sense to do that for continuous variables.  For categorical variables it gives you even more information to ask "how many observations do I have per unique value?" which includes the answer to the first question.
#
# In order to answer any of these, you would need to be able to take one variable at a time, or in some cases one observation at a time. Let's play with some subsetting opeations to get you warmed up.
#
# Subsetting is the act of selecting lower-dimensional slices of a multi-dimensional object.

# %% [markdown]
# ### Subsetting

# %%
type(data[['YearStart', 'LocationAbbr']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Question:**  What is the type of the object retuned by the above?

# %% [markdown]
# ### Counting starts at 0

# %% [markdown]
# Python, and all languages in the C family including Java, Perl, Python, C++, start counting at 0, not 1. This represents the number of steps it takes for us to get to the element we are interested in.
#
# This is in contrast to MATLAB, R, and Fortran where you will notice that the first element in e.g. a vector is element 1, not 0.
#
# This means that in order to get the first element of the YearStart Series, I would need to write:

# %%
data['YearStart'][0:10:2]
# Out:
# 0    2013
# 2    2013
# 4    2013
# 6    2013
# 8    2013
# Name: YearStart, dtype: int64

# %% [markdown]
# **Question:** What does the : do?

# %%
data[0:10]
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2013     2013           AK                Alaska      YRBSS  Alcohol
# 1       2013     2013           AL               Alabama      YRBSS  Alcohol
# 2       2013     2013           AR              Arkansas      YRBSS  Alcohol
# 3       2013     2013           AZ               Arizona      YRBSS  Alcohol
# 4       2013     2013           CA            California      YRBSS  Alcohol
# 5       2013     2013           CO              Colorado      YRBSS  Alcohol
# 6       2013     2013           CT           Connecticut      YRBSS  Alcohol
# 7       2013     2013           DC  District of Columbia      YRBSS  Alcohol
# 8       2013     2013           DE              Delaware      YRBSS  Alcohol
# 9       2013     2013           FL               Florida      YRBSS  Alcohol
#
#                   Question DataValueUnit     DataValueType DataValue  \
# 0  Alcohol use among youth             %  Crude Prevalence      22.5
# 1  Alcohol use among youth             %  Crude Prevalence        35
# 2  Alcohol use among youth             %  Crude Prevalence      36.3
# 3  Alcohol use among youth             %  Crude Prevalence        36
# 4  Alcohol use among youth             %  Crude Prevalence       NaN
# 5  Alcohol use among youth             %  Crude Prevalence       NaN
# 6  Alcohol use among youth             %  Crude Prevalence      36.7
# 7  Alcohol use among youth             %  Crude Prevalence      31.4
# 8  Alcohol use among youth             %  Crude Prevalence      36.3
# 9  Alcohol use among youth             %  Crude Prevalence      34.8
#
#          ...         HighConfidenceLimit StratificationCategory1  \
# 0        ...                        26.1                 Overall
# 1        ...                        40.3                 Overall
# 2        ...                        40.4                 Overall
# 3        ...                        40.9                 Overall
# 4        ...                         NaN                 Overall
# 5        ...                         NaN                 Overall
# 6        ...                        41.0                 Overall
# 7        ...                        32.5                 Overall
# 8        ...                        39.0                 Overall
# 9        ...                        36.6                 Overall
#
#   Stratification1                                GeoLocation  LocationID  \
# 0         Overall   (64.84507995700051, -147.72205903599973)           2
# 1         Overall    (32.84057112200048, -86.63186076199969)           1
# 2         Overall    (34.74865012400045, -92.27449074299966)           5
# 3         Overall  (34.865970280000454, -111.76381127699972)           4
# 4         Overall   (37.63864012300047, -120.99999953799971)           6
# 5         Overall  (38.843840757000464, -106.13361092099967)           8
# 6         Overall    (41.56266102000046, -72.64984095199964)           9
# 7         Overall                    (38.907192, -77.036871)          11
# 8         Overall   (39.008830667000495, -75.57774116799965)          10
# 9         Overall   (28.932040377000476, -81.92896053899966)          12
#
#   TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0     ALC     ALC1_1         CrdPrev                    OVERALL
# 1     ALC     ALC1_1         CrdPrev                    OVERALL
# 2     ALC     ALC1_1         CrdPrev                    OVERALL
# 3     ALC     ALC1_1         CrdPrev                    OVERALL
# 4     ALC     ALC1_1         CrdPrev                    OVERALL
# 5     ALC     ALC1_1         CrdPrev                    OVERALL
# 6     ALC     ALC1_1         CrdPrev                    OVERALL
# 7     ALC     ALC1_1         CrdPrev                    OVERALL
# 8     ALC     ALC1_1         CrdPrev                    OVERALL
# 9     ALC     ALC1_1         CrdPrev                    OVERALL
#
#   StratificationID1
# 0               OVR
# 1               OVR
# 2               OVR
# 3               OVR
# 4               OVR
# 5               OVR
# 6               OVR
# 7               OVR
# 8               OVR
# 9               OVR
#
# [10 rows x 24 columns]

# %% [markdown]
# **Question:** What does the expression below do?

# %% [markdown]
# There are lots of ways to subset this pandas DataFrame. One way is to use the isin() method, which allows us to filter by value of a variable.
#
# Let's try that for filtering only the records that represent data on Florida, abbreviated as FL, and ask to return how many of them there are.

# %%
florida = data[data['LocationAbbr'].isin(['FL'])]
# Out:
# (3026, 24)

# %%
data[data['LocationAbbr'].isin(['FL'])].shape
# Out:
# (3026, 24)

# %% [markdown]
# **Exercise:** In the cell below, write an expression that will return the CrudePrevalence of "Alcohol use among youth" for the state of Florida in the year 2013.

# %%
data[data['LocationAbbr'].isin(['FL']) & data['DataValueType'].isin(['Crude Prevalence'])& data['YearStart'].isin(['2013']) & data['Question'].isin(['Alcohol use among youth'])]
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource    Topic  \
# 9       2013     2013           FL      Florida      YRBSS  Alcohol
#
#                   Question DataValueUnit     DataValueType DataValue  \
# 9  Alcohol use among youth             %  Crude Prevalence      34.8
#
#          ...         HighConfidenceLimit StratificationCategory1  \
# 9        ...                        36.6                 Overall
#
#   Stratification1                               GeoLocation  LocationID  \
# 9         Overall  (28.932040377000476, -81.92896053899966)          12
#
#   TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 9     ALC     ALC1_1         CrdPrev                    OVERALL
#
#   StratificationID1
# 9               OVR
#
# [1 rows x 24 columns]

# %% [markdown]
# Another two key methods to know from pandas is .loc() and .iloc()
#
# **Question:** Look up what they do and how to use them in the pandas documentation.
#
# **Exercise:** Write an expression that subsets anything you want out of the data using .loc() or .iloc()

# %%
type(data.iloc[['3', '4']])
type(data[3:5])

type(data.iloc[3])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Quality control, preprocessing and exploratory analyses

# %% [markdown]
# Cleaning your data, preprocessing, quality control (QC) and exploratory analyses are all words that we use to describe inter-related processes.
#
# This stage is where you'll spend the majority of your time. Once you have data that you can trust, you can do all kinds of analyses on it. But it is crucial that you first gain trust in the data.
#
# In our example, most of the QC and preprocessing has been done for us by the analysts at the CDC. It is generally a good idea for those doing the QC to be as close to the data collection as possible - their knowledge of the data generation process is an advantage in both identifying and deciding how to deal with QC issues.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# The term "preprocessing" refers to manipulations such as:
# * converting all measurements of e.g. distance to the same unit
# * consolidating how missing data is represented into a common value
# * consolidating values into a unique set (most often a problem with survey data, particularly with free text where you may have a variety of responses that all mean the same thing)
# * merging your data with another dataset
# * normalizing the measurements to a common standard
#
# Often, you will find that you'll also need to reshape your data so that libraries that were designed to work with data in a specific format can be used in your analysis.
#
# Lastly, some may argue that variable transformations are also part of the pre-processing routine. Transformations may be necessary for a number of reasons, for example, if a continuous variable v is Poisson distributed you may want to use log(v) in your analysis instead.

# %% [markdown]
# ## Quality control and data cleaning

# %% [markdown]
# The terms "cleaning" and "quality control" refer to manipulations such as:
# * removing untrusted observations
# * removing entire columns or rows of data depending on a set of filtering criteria
# * identifying any structure in the data that doesn't have to do with the variables that you are interested in but rather with how the data was collected
#
# **Question:** Under what conditions would you want to remove a column rather than simply ignore it in your analyses?
#
# **Question:** If we were performing an fMRI study and had data from multiple scanners in our dataset, there will be structure in the data that reflects the difference in scanners rather than a variable of interest. Under what conditions would this be a problem?
#
# **Question:** In the example above with the multiple MRI scanners, why is this under QC?
#
# The goal is to end up with a dataset that you can confidently analyze, a dataset that you can trust actually represents the reality of what was measured.
#
# Many fields have figured out what the standard QC metrics are for their type of data. For example, for genetic data generated using microarray technology, the standard set of QC procedures include checking that the genotypic sex of the sample matches the manifest, applying filters that exclude samples with >5% of genotypes missing, and filters that exclude genotypes missing in >5% of the samples. These often represent sample mix ups, a low quality DNA sample, or failed genotyping assay respectively.
#
# You should think critically through each of the QC filters that you apply.  Depending on the question you are asking and on other properties of the data, the standard filters may not be appropriate for your analysis! It is really, really important to let the data and your questions guide your QC approach, rather than follow a protocol blindly. Granted, you will most likely end up not deviating from the protocol, especially if it's been around for long enough to be well refined, but it will be your job as a data scientist to make sure that you know why you are applying a QC filter and why you are choosing a specific filtering threshold over another.

# %% [markdown]
# ## Exploratory analyses

# %% [markdown]
# Exploratory analyses often feed back into pre-processing and QC because they identify issues that can be addressed by e.g. transforming a variable or e.g. applying a QC filter.
#
# In addition, exploratory analyses calibrate your intuition for the data, gives you a feel for the information that is available, and the information that is not available given how the data was collected.
#
# Some things that you can do to explore your data are:
# * plot the distributions of variables and get some descriptive statistics
# * plot scatterplots to get a sense for the relationship between variables
#
# There are three main categories of descriptive statistics:
# * frequencies
# * measures of central tendency
# * measures of variation.
#
# Which of these will be meaningful depends on the type of variable that you have.
#
# **Question:** What are the various types of variables? How are they related to each other?

# %% [markdown]
# ### Frequency tables

# %% [markdown]
# For categorical variables, it is useful to create frequency tables for each of the values.
#
# The pandas library has a method .value_counts() that does that for a Series object. .value_count() can also be used as a function on array objects from the Python Standard Library.
#
# Let's try it to answer the question "how many rows do we have in the Chronic Disease Indicators data for each state?"

# %%
data['LocationAbbr'].value_counts()
# Out:
# NV    3057
# SC    3057
# NE    3057
# NJ    3057
# KY    3057
# NC    3057
# NY    3057
# VT    3057
# WI    3057
# NM    3042
# MS    3042
# OK    3042
# LA    3042
# TX    3042
# WY    3042
# UT    3042
# ND    3042
# MT    3042
# RI    3042
# MI    3042
# IN    3042
# MO    3042
# MD    3042
# WV    3042
# KS    3042
# MN    3042
# VA    3042
# SD    3042
# WA    3042
# ME    3042
# PA    3042
# TN    3042
# OR    3042
# OH    3042
# NH    3042
# MA    3042
# FL    3026
# IA    3025
# AZ    3025
# GA    3010
# CA    3010
# AR    3010
# ID    3010
# CT    3010
# DC    3010
# IL    3010
# DE    3010
# AL    3010
# AK    3010
# HI    3010
# CO    3010
# VI    1556
# PR    1556
# GU    1524
# US     788
# Name: LocationAbbr, dtype: int64

# %% [markdown]
# **Question:** What is the type of the object returned by the .value_counts() method?
#
# **Exercise:** In the cell below, write an expression that will return the value counts for the column Topic just for the state of FL.

# %%
florida['YearEnd'].value_counts()
# Out:
# 2013    58812
# 2014    54258
# 2010    16704
# 2012    15274
# 2011    15219
# Name: YearEnd, dtype: int64

# %% [markdown]
# **Exercise:** In the cells below, write expressions that will return:
# 1. The value counts for the topics covered by the CDI instruments.
# 2. The value counts for the questions asked for the topic "Alcohol".

# %%
data['Topic'].value_counts()
# Out:
# Cardiovascular Disease                   40224
# Diabetes                                 33257
# Chronic Obstructive Pulmonary Disease    27126
# Asthma                                   16592
# Alcohol                                  14890
# Arthritis                                12510
# Chronic Kidney Disease                    7875
# Cancer                                    4120
# Mental Health                             2445
# Immunization                              1228
# Name: Topic, dtype: int64

# %%
alcohol = data[data['Topic'].isin(['Alcohol'])]
alcohol['Question'].value_counts()
# Out:
# Chronic liver disease mortality                                           6135
# Binge drinking frequency among adults aged >= 18 years who binge drink    1740
# Binge drinking intensity among adults aged >= 18 years who binge drink    1740
# Binge drinking prevalence among adults aged >= 18 years                   1740
# Heavy drinking among adults aged >= 18 years                              1740
# Heavy drinking among women aged 18-44 years                                650
# Binge drinking prevalence among women aged 18-44 years                     650
# Commercial host (dram shop) liability laws                                  55
# Amount of alcohol excise tax by beverage type (beer)                        55
# Alcohol use before pregnancy                                                55
# Amount of alcohol excise tax by beverage type (wine)                        55
# Per capita alcohol consumption among persons aged >= 14 years               55
# Binge drinking prevalence among youth                                       55
# Amount of alcohol excise tax by beverage type (distilled spirits)           55
# Alcohol use among youth                                                     55
# Local authority to regulate alcohol outlet density                          55
# Name: Question, dtype: int64

# %% [markdown]
# There seem to be lots more entries for Chronic liver disease mortality than there are for the other variables. If you look closely, you may get the idea that the other questions are more narrow in their scope. "among women aged .." limits the segment of the population that is relevant, in a way that "Chronic liver disease mortality doesn't".
#
# Is this additional information from presumably what may be a wider segment of the population coming from all the states equally, or are some states contributing to the differences in these values disproportionately? In other words, could this be due to missing data?
#
# (It's unlikely that it's due to missing data given the even-ness of the values, i.e. there are lots of 1740, lots of 55, etc. But we'll look anyway.)
#
# So let's zoom in, limiting our view to the states captured by LocationAbbr, to find out the distribution of these questions across the states.

# %%
pd.crosstab(alcohol['Question'], alcohol['LocationAbbr'])
# Out:
# LocationAbbr                                         AK   AL   AR   AZ   CA  \
# Question
# Alcohol use among youth                               1    1    1    1    1
# Alcohol use before pregnancy                          1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...    1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...    1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...    1    1    1    1    1
# Binge drinking frequency among adults aged >= 1...   32   32   32   32   32
# Binge drinking intensity among adults aged >= 1...   32   32   32   32   32
# Binge drinking prevalence among adults aged >= ...   32   32   32   32   32
# Binge drinking prevalence among women aged 18-4...   12   12   12   12   12
# Binge drinking prevalence among youth                 1    1    1    1    1
# Chronic liver disease mortality                     120  120  120  120  120
# Commercial host (dram shop) liability laws            1    1    1    1    1
# Heavy drinking among adults aged >= 18 years         32   32   32   32   32
# Heavy drinking among women aged 18-44 years          12   12   12   12   12
# Local authority to regulate alcohol outlet density    1    1    1    1    1
# Per capita alcohol consumption among persons ag...    1    1    1    1    1
#
# LocationAbbr                                         CO   CT   DC   DE   FL  \
# Question
# Alcohol use among youth                               1    1    1    1    1
# Alcohol use before pregnancy                          1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...    1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...    1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...    1    1    1    1    1
# Binge drinking frequency among adults aged >= 1...   32   32   32   32   32
# Binge drinking intensity among adults aged >= 1...   32   32   32   32   32
# Binge drinking prevalence among adults aged >= ...   32   32   32   32   32
# Binge drinking prevalence among women aged 18-4...   12   12   12   12   12
# Binge drinking prevalence among youth                 1    1    1    1    1
# Chronic liver disease mortality                     120  120  120  120  120
# Commercial host (dram shop) liability laws            1    1    1    1    1
# Heavy drinking among adults aged >= 18 years         32   32   32   32   32
# Heavy drinking among women aged 18-44 years          12   12   12   12   12
# Local authority to regulate alcohol outlet density    1    1    1    1    1
# Per capita alcohol consumption among persons ag...    1    1    1    1    1
#
# LocationAbbr                                       ...    TX  US   UT   VA  \
# Question                                           ...
# Alcohol use among youth                            ...     1   1    1    1
# Alcohol use before pregnancy                       ...     1   1    1    1
# Amount of alcohol excise tax by beverage type (... ...     1   1    1    1
# Amount of alcohol excise tax by beverage type (... ...     1   1    1    1
# Amount of alcohol excise tax by beverage type (... ...     1   1    1    1
# Binge drinking frequency among adults aged >= 1... ...    32  12   32   32
# Binge drinking intensity among adults aged >= 1... ...    32  12   32   32
# Binge drinking prevalence among adults aged >= ... ...    32  12   32   32
# Binge drinking prevalence among women aged 18-4... ...    12   2   12   12
# Binge drinking prevalence among youth              ...     1   1    1    1
# Chronic liver disease mortality                    ...   120  15  120  120
# Commercial host (dram shop) liability laws         ...     1   1    1    1
# Heavy drinking among adults aged >= 18 years       ...    32  12   32   32
# Heavy drinking among women aged 18-44 years        ...    12   2   12   12
# Local authority to regulate alcohol outlet density ...     1   1    1    1
# Per capita alcohol consumption among persons ag... ...     1   1    1    1
#
# LocationAbbr                                        VI   VT   WA   WI   WV  \
# Question
# Alcohol use among youth                              1    1    1    1    1
# Alcohol use before pregnancy                         1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...   1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...   1    1    1    1    1
# Amount of alcohol excise tax by beverage type (...   1    1    1    1    1
# Binge drinking frequency among adults aged >= 1...  32   32   32   32   32
# Binge drinking intensity among adults aged >= 1...  32   32   32   32   32
# Binge drinking prevalence among adults aged >= ...  32   32   32   32   32
# Binge drinking prevalence among women aged 18-4...  12   12   12   12   12
# Binge drinking prevalence among youth                1    1    1    1    1
# Chronic liver disease mortality                      0  120  120  120  120
# Commercial host (dram shop) liability laws           1    1    1    1    1
# Heavy drinking among adults aged >= 18 years        32   32   32   32   32
# Heavy drinking among women aged 18-44 years         12   12   12   12   12
# Local authority to regulate alcohol outlet density   1    1    1    1    1
# Per capita alcohol consumption among persons ag...   1    1    1    1    1
#
# LocationAbbr                                         WY
# Question
# Alcohol use among youth                               1
# Alcohol use before pregnancy                          1
# Amount of alcohol excise tax by beverage type (...    1
# Amount of alcohol excise tax by beverage type (...    1
# Amount of alcohol excise tax by beverage type (...    1
# Binge drinking frequency among adults aged >= 1...   32
# Binge drinking intensity among adults aged >= 1...   32
# Binge drinking prevalence among adults aged >= ...   32
# Binge drinking prevalence among women aged 18-4...   12
# Binge drinking prevalence among youth                 1
# Chronic liver disease mortality                     120
# Commercial host (dram shop) liability laws            1
# Heavy drinking among adults aged >= 18 years         32
# Heavy drinking among women aged 18-44 years          12
# Local authority to regulate alcohol outlet density    1
# Per capita alcohol consumption among persons ag...    1
#
# [16 rows x 55 columns]

# %% [markdown]
# It seems that more or less, states have data on the same questions as each other, or at least that they have cells for those values, whether or not those cells are NaN or empty.
#
# We have a good amount of information for Chronic liver disease mortality, so let's see how it breaks down into categories.

# %%
alcohol[alcohol['LocationAbbr'].isin(['FL']) 
        & alcohol['Question'].isin(['Chronic liver disease mortality'])]
# Out:
#       YearStart  YearEnd LocationAbbr LocationDesc DataSource    Topic  \
# 1222       2010     2010           FL      Florida       NVSS  Alcohol
# 1264       2010     2010           FL      Florida       NVSS  Alcohol
# 9589       2010     2010           FL      Florida       NVSS  Alcohol
# 9590       2010     2010           FL      Florida       NVSS  Alcohol
# 9591       2010     2010           FL      Florida       NVSS  Alcohol
# 9592       2010     2010           FL      Florida       NVSS  Alcohol
# 9593       2010     2010           FL      Florida       NVSS  Alcohol
# 9594       2010     2010           FL      Florida       NVSS  Alcohol
# 9595       2010     2010           FL      Florida       NVSS  Alcohol
# 9596       2010     2010           FL      Florida       NVSS  Alcohol
# 9597       2010     2010           FL      Florida       NVSS  Alcohol
# 9598       2010     2010           FL      Florida       NVSS  Alcohol
# 9599       2010     2010           FL      Florida       NVSS  Alcohol
# 9600       2010     2010           FL      Florida       NVSS  Alcohol
# 9601       2010     2010           FL      Florida       NVSS  Alcohol
# 9602       2010     2010           FL      Florida       NVSS  Alcohol
# 9603       2010     2010           FL      Florida       NVSS  Alcohol
# 9604       2010     2010           FL      Florida       NVSS  Alcohol
# 9605       2010     2010           FL      Florida       NVSS  Alcohol
# 9606       2010     2010           FL      Florida       NVSS  Alcohol
# 9607       2010     2010           FL      Florida       NVSS  Alcohol
# 9608       2010     2010           FL      Florida       NVSS  Alcohol
# 9609       2010     2010           FL      Florida       NVSS  Alcohol
# 9610       2010     2010           FL      Florida       NVSS  Alcohol
# 9611       2011     2011           FL      Florida       NVSS  Alcohol
# 9612       2011     2011           FL      Florida       NVSS  Alcohol
# 9613       2011     2011           FL      Florida       NVSS  Alcohol
# 9614       2011     2011           FL      Florida       NVSS  Alcohol
# 9615       2011     2011           FL      Florida       NVSS  Alcohol
# 9616       2011     2011           FL      Florida       NVSS  Alcohol
# ...         ...      ...          ...          ...        ...      ...
# 9677       2013     2013           FL      Florida       NVSS  Alcohol
# 9678       2013     2013           FL      Florida       NVSS  Alcohol
# 9679       2013     2013           FL      Florida       NVSS  Alcohol
# 9680       2013     2013           FL      Florida       NVSS  Alcohol
# 9681       2013     2013           FL      Florida       NVSS  Alcohol
# 9682       2013     2013           FL      Florida       NVSS  Alcohol
# 9683       2014     2014           FL      Florida       NVSS  Alcohol
# 9684       2014     2014           FL      Florida       NVSS  Alcohol
# 9685       2014     2014           FL      Florida       NVSS  Alcohol
# 9686       2014     2014           FL      Florida       NVSS  Alcohol
# 9687       2014     2014           FL      Florida       NVSS  Alcohol
# 9688       2014     2014           FL      Florida       NVSS  Alcohol
# 9689       2014     2014           FL      Florida       NVSS  Alcohol
# 9690       2014     2014           FL      Florida       NVSS  Alcohol
# 9691       2014     2014           FL      Florida       NVSS  Alcohol
# 9692       2014     2014           FL      Florida       NVSS  Alcohol
# 9693       2014     2014           FL      Florida       NVSS  Alcohol
# 9694       2014     2014           FL      Florida       NVSS  Alcohol
# 9695       2014     2014           FL      Florida       NVSS  Alcohol
# 9696       2014     2014           FL      Florida       NVSS  Alcohol
# 9697       2014     2014           FL      Florida       NVSS  Alcohol
# 9698       2014     2014           FL      Florida       NVSS  Alcohol
# 9699       2014     2014           FL      Florida       NVSS  Alcohol
# 9700       2014     2014           FL      Florida       NVSS  Alcohol
# 9701       2014     2014           FL      Florida       NVSS  Alcohol
# 9702       2014     2014           FL      Florida       NVSS  Alcohol
# 9703       2014     2014           FL      Florida       NVSS  Alcohol
# 9704       2014     2014           FL      Florida       NVSS  Alcohol
# 9705       2014     2014           FL      Florida       NVSS  Alcohol
# 9706       2014     2014           FL      Florida       NVSS  Alcohol
#
#                              Question      DataValueUnit      DataValueType  \
# 1222  Chronic liver disease mortality                NaN             Number
# 1264  Chronic liver disease mortality                NaN             Number
# 9589  Chronic liver disease mortality                NaN             Number
# 9590  Chronic liver disease mortality                NaN             Number
# 9591  Chronic liver disease mortality                NaN             Number
# 9592  Chronic liver disease mortality                NaN             Number
# 9593  Chronic liver disease mortality                NaN             Number
# 9594  Chronic liver disease mortality                NaN             Number
# 9595  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9596  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9597  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9598  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9599  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9600  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9601  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9602  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9603  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9604  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9605  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9606  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9607  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9608  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9609  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9610  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9611  Chronic liver disease mortality                NaN             Number
# 9612  Chronic liver disease mortality                NaN             Number
# 9613  Chronic liver disease mortality                NaN             Number
# 9614  Chronic liver disease mortality                NaN             Number
# 9615  Chronic liver disease mortality                NaN             Number
# 9616  Chronic liver disease mortality                NaN             Number
# ...                               ...                ...                ...
# 9677  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9678  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9679  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9680  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9681  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9682  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9683  Chronic liver disease mortality                NaN             Number
# 9684  Chronic liver disease mortality                NaN             Number
# 9685  Chronic liver disease mortality                NaN             Number
# 9686  Chronic liver disease mortality                NaN             Number
# 9687  Chronic liver disease mortality                NaN             Number
# 9688  Chronic liver disease mortality                NaN             Number
# 9689  Chronic liver disease mortality                NaN             Number
# 9690  Chronic liver disease mortality                NaN             Number
# 9691  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9692  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9693  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9694  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9695  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9696  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9697  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9698  Chronic liver disease mortality  cases per 100,000         Crude Rate
# 9699  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9700  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9701  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9702  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9703  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9704  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9705  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9706  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
#
#      DataValue        ...         HighConfidenceLimit StratificationCategory1  \
# 1222       147        ...                         NaN          Race/Ethnicity
# 1264       302        ...                         NaN          Race/Ethnicity
# 9589      2480        ...                         NaN                 Overall
# 9590      1618        ...                         NaN                  Gender
# 9591       862        ...                         NaN                  Gender
# 9592      1995        ...                         NaN          Race/Ethnicity
# 9593                  ...                         NaN          Race/Ethnicity
# 9594                  ...                         NaN          Race/Ethnicity
# 9595      13.2        ...                        13.7                 Overall
# 9596      17.6        ...                        18.5                  Gender
# 9597       9.0        ...                         9.6                  Gender
# 9598      18.0        ...                        18.8          Race/Ethnicity
# 9599                  ...                         NaN          Race/Ethnicity
# 9600                  ...                         NaN          Race/Ethnicity
# 9601       5.0        ...                         5.8          Race/Ethnicity
# 9602       7.1        ...                         8.0          Race/Ethnicity
# 9603      10.6        ...                        11.0                 Overall
# 9604      14.6        ...                        15.3                  Gender
# 9605       7.0        ...                         7.5                  Gender
# 9606      12.7        ...                        13.3          Race/Ethnicity
# 9607                  ...                         NaN          Race/Ethnicity
# 9608                  ...                         NaN          Race/Ethnicity
# 9609       5.6        ...                         6.5          Race/Ethnicity
# 9610       8.0        ...                         8.9          Race/Ethnicity
# 9611      2590        ...                         NaN                 Overall
# 9612      1659        ...                         NaN                  Gender
# 9613       931        ...                         NaN                  Gender
# 9614      2075        ...                         NaN          Race/Ethnicity
# 9615        21        ...                         NaN          Race/Ethnicity
# 9616                  ...                         NaN          Race/Ethnicity
# ...        ...        ...                         ...                     ...
# 9677       7.1        ...                         7.6                  Gender
# 9678      13.3        ...                        13.9          Race/Ethnicity
# 9679                  ...                         NaN          Race/Ethnicity
# 9680                  ...                         NaN          Race/Ethnicity
# 9681       4.8        ...                         5.6          Race/Ethnicity
# 9682       7.4        ...                         8.2          Race/Ethnicity
# 9683      3037        ...                         NaN                 Overall
# 9684      1971        ...                         NaN                  Gender
# 9685      1066        ...                         NaN                  Gender
# 9686      2475        ...                         NaN          Race/Ethnicity
# 9687                  ...                         NaN          Race/Ethnicity
# 9688                  ...                         NaN          Race/Ethnicity
# 9689       158        ...                         NaN          Race/Ethnicity
# 9690       368        ...                         NaN          Race/Ethnicity
# 9691      15.3        ...                        15.8                 Overall
# 9692      20.3        ...                        21.2                  Gender
# 9693      10.5        ...                        11.1                  Gender
# 9694      22.0        ...                        22.8          Race/Ethnicity
# 9695                  ...                         NaN          Race/Ethnicity
# 9696                  ...                         NaN          Race/Ethnicity
# 9697       5.0        ...                         5.7          Race/Ethnicity
# 9698       7.7        ...                         8.5          Race/Ethnicity
# 9699      11.8        ...                        12.3                 Overall
# 9700      16.2        ...                        16.9                  Gender
# 9701       8.0        ...                         8.5                  Gender
# 9702      15.1        ...                        15.8          Race/Ethnicity
# 9703                  ...                         NaN          Race/Ethnicity
# 9704                  ...                         NaN          Race/Ethnicity
# 9705       5.3        ...                         6.1          Race/Ethnicity
# 9706       8.0        ...                         8.8          Race/Ethnicity
#
#                        Stratification1  \
# 1222               Black, non-Hispanic
# 1264                          Hispanic
# 9589                           Overall
# 9590                              Male
# 9591                            Female
# 9592               White, non-Hispanic
# 9593         Asian or Pacific Islander
# 9594  American Indian or Alaska Native
# 9595                           Overall
# 9596                              Male
# 9597                            Female
# 9598               White, non-Hispanic
# 9599         Asian or Pacific Islander
# 9600  American Indian or Alaska Native
# 9601               Black, non-Hispanic
# 9602                          Hispanic
# 9603                           Overall
# 9604                              Male
# 9605                            Female
# 9606               White, non-Hispanic
# 9607         Asian or Pacific Islander
# 9608  American Indian or Alaska Native
# 9609               Black, non-Hispanic
# 9610                          Hispanic
# 9611                           Overall
# 9612                              Male
# 9613                            Female
# 9614               White, non-Hispanic
# 9615         Asian or Pacific Islander
# 9616  American Indian or Alaska Native
# ...                                ...
# 9677                            Female
# 9678               White, non-Hispanic
# 9679         Asian or Pacific Islander
# 9680  American Indian or Alaska Native
# 9681               Black, non-Hispanic
# 9682                          Hispanic
# 9683                           Overall
# 9684                              Male
# 9685                            Female
# 9686               White, non-Hispanic
# 9687         Asian or Pacific Islander
# 9688  American Indian or Alaska Native
# 9689               Black, non-Hispanic
# 9690                          Hispanic
# 9691                           Overall
# 9692                              Male
# 9693                            Female
# 9694               White, non-Hispanic
# 9695         Asian or Pacific Islander
# 9696  American Indian or Alaska Native
# 9697               Black, non-Hispanic
# 9698                          Hispanic
# 9699                           Overall
# 9700                              Male
# 9701                            Female
# 9702               White, non-Hispanic
# 9703         Asian or Pacific Islander
# 9704  American Indian or Alaska Native
# 9705               Black, non-Hispanic
# 9706                          Hispanic
#
#                                    GeoLocation  LocationID TopicID QuestionID  \
# 1222  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 1264  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9589  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9590  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9591  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9592  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9593  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9594  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9595  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9596  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9597  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9598  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9599  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9600  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9601  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9602  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9603  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9604  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9605  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9606  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9607  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9608  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9609  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9610  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9611  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9612  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9613  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9614  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9615  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9616  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# ...                                        ...         ...     ...        ...
# 9677  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9678  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9679  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9680  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9681  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9682  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9683  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9684  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9685  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9686  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9687  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9688  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9689  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9690  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9691  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9692  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9693  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9694  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9695  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9696  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9697  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9698  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9699  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9700  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9701  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9702  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9703  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9704  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9705  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9706  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
#
#      DataValueTypeID  StratificationCategoryID1 StratificationID1
# 1222            Nmbr                       RACE               BLK
# 1264            Nmbr                       RACE               HIS
# 9589            Nmbr                    OVERALL               OVR
# 9590            Nmbr                     GENDER              GENM
# 9591            Nmbr                     GENDER              GENF
# 9592            Nmbr                       RACE               WHT
# 9593            Nmbr                       RACE               API
# 9594            Nmbr                       RACE              AIAN
# 9595         CrdRate                    OVERALL               OVR
# 9596         CrdRate                     GENDER              GENM
# 9597         CrdRate                     GENDER              GENF
# 9598         CrdRate                       RACE               WHT
# 9599         CrdRate                       RACE               API
# 9600         CrdRate                       RACE              AIAN
# 9601         CrdRate                       RACE               BLK
# 9602         CrdRate                       RACE               HIS
# 9603      AgeAdjRate                    OVERALL               OVR
# 9604      AgeAdjRate                     GENDER              GENM
# 9605      AgeAdjRate                     GENDER              GENF
# 9606      AgeAdjRate                       RACE               WHT
# 9607      AgeAdjRate                       RACE               API
# 9608      AgeAdjRate                       RACE              AIAN
# 9609      AgeAdjRate                       RACE               BLK
# 9610      AgeAdjRate                       RACE               HIS
# 9611            Nmbr                    OVERALL               OVR
# 9612            Nmbr                     GENDER              GENM
# 9613            Nmbr                     GENDER              GENF
# 9614            Nmbr                       RACE               WHT
# 9615            Nmbr                       RACE               API
# 9616            Nmbr                       RACE              AIAN
# ...              ...                        ...               ...
# 9677      AgeAdjRate                     GENDER              GENF
# 9678      AgeAdjRate                       RACE               WHT
# 9679      AgeAdjRate                       RACE               API
# 9680      AgeAdjRate                       RACE              AIAN
# 9681      AgeAdjRate                       RACE               BLK
# 9682      AgeAdjRate                       RACE               HIS
# 9683            Nmbr                    OVERALL               OVR
# 9684            Nmbr                     GENDER              GENM
# 9685            Nmbr                     GENDER              GENF
# 9686            Nmbr                       RACE               WHT
# 9687            Nmbr                       RACE               API
# 9688            Nmbr                       RACE              AIAN
# 9689            Nmbr                       RACE               BLK
# 9690            Nmbr                       RACE               HIS
# 9691         CrdRate                    OVERALL               OVR
# 9692         CrdRate                     GENDER              GENM
# 9693         CrdRate                     GENDER              GENF
# 9694         CrdRate                       RACE               WHT
# 9695         CrdRate                       RACE               API
# 9696         CrdRate                       RACE              AIAN
# 9697         CrdRate                       RACE               BLK
# 9698         CrdRate                       RACE               HIS
# 9699      AgeAdjRate                    OVERALL               OVR
# 9700      AgeAdjRate                     GENDER              GENM
# 9701      AgeAdjRate                     GENDER              GENF
# 9702      AgeAdjRate                       RACE               WHT
# 9703      AgeAdjRate                       RACE               API
# 9704      AgeAdjRate                       RACE              AIAN
# 9705      AgeAdjRate                       RACE               BLK
# 9706      AgeAdjRate                       RACE               HIS
#
# [120 rows x 24 columns]

# %% [markdown]
# We see that we have two main variables that vary when we look within the Alcohol questions just for the state of Florida.
#
# These are the **DataValueType**, which captures epidemiological estimates (number of cases, crude rate per 100,000, and age-adjusted rate per 100,000), and **StratificationCategory1** which captures population segments (based on sex Male or Female, and Race/Ethnicity (Hispanic, Black non-Hispanic, American Indian or Alaska Native, White non-Hispanic, and Asian or Pacific Islander).
#
# So let's filter those out, in preparation to make a bar-plot that may allow us to get a **descriptive** comparison of the age-adjusted rate for chronic liver disease mortality across Race/Ethnicity.

# %%
alcohol[alcohol['LocationAbbr'].isin(['FL']) 
        & alcohol['Question'].isin(['Chronic liver disease mortality'])
        & alcohol['DataValueType'].isin(['Age-adjusted Rate'])
        & alcohol['StratificationCategory1'].isin(['Race/Ethnicity'])]
# Out:
#       YearStart  YearEnd LocationAbbr LocationDesc DataSource    Topic  \
# 9606       2010     2010           FL      Florida       NVSS  Alcohol
# 9607       2010     2010           FL      Florida       NVSS  Alcohol
# 9608       2010     2010           FL      Florida       NVSS  Alcohol
# 9609       2010     2010           FL      Florida       NVSS  Alcohol
# 9610       2010     2010           FL      Florida       NVSS  Alcohol
# 9630       2011     2011           FL      Florida       NVSS  Alcohol
# 9631       2011     2011           FL      Florida       NVSS  Alcohol
# 9632       2011     2011           FL      Florida       NVSS  Alcohol
# 9633       2011     2011           FL      Florida       NVSS  Alcohol
# 9634       2011     2011           FL      Florida       NVSS  Alcohol
# 9654       2012     2012           FL      Florida       NVSS  Alcohol
# 9655       2012     2012           FL      Florida       NVSS  Alcohol
# 9656       2012     2012           FL      Florida       NVSS  Alcohol
# 9657       2012     2012           FL      Florida       NVSS  Alcohol
# 9658       2012     2012           FL      Florida       NVSS  Alcohol
# 9678       2013     2013           FL      Florida       NVSS  Alcohol
# 9679       2013     2013           FL      Florida       NVSS  Alcohol
# 9680       2013     2013           FL      Florida       NVSS  Alcohol
# 9681       2013     2013           FL      Florida       NVSS  Alcohol
# 9682       2013     2013           FL      Florida       NVSS  Alcohol
# 9702       2014     2014           FL      Florida       NVSS  Alcohol
# 9703       2014     2014           FL      Florida       NVSS  Alcohol
# 9704       2014     2014           FL      Florida       NVSS  Alcohol
# 9705       2014     2014           FL      Florida       NVSS  Alcohol
# 9706       2014     2014           FL      Florida       NVSS  Alcohol
#
#                              Question      DataValueUnit      DataValueType  \
# 9606  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9607  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9608  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9609  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9610  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9630  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9631  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9632  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9633  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9634  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9654  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9655  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9656  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9657  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9658  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9678  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9679  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9680  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9681  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9682  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9702  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9703  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9704  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9705  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
# 9706  Chronic liver disease mortality  cases per 100,000  Age-adjusted Rate
#
#      DataValue        ...         HighConfidenceLimit StratificationCategory1  \
# 9606      12.7        ...                        13.3          Race/Ethnicity
# 9607                  ...                         NaN          Race/Ethnicity
# 9608                  ...                         NaN          Race/Ethnicity
# 9609       5.6        ...                         6.5          Race/Ethnicity
# 9610       8.0        ...                         8.9          Race/Ethnicity
# 9630      13.0        ...                        13.6          Race/Ethnicity
# 9631       4.7        ...                         7.3          Race/Ethnicity
# 9632                  ...                         NaN          Race/Ethnicity
# 9633       5.9        ...                         6.9          Race/Ethnicity
# 9634       8.0        ...                         8.9          Race/Ethnicity
# 9654      12.8        ...                        13.4          Race/Ethnicity
# 9655                  ...                         NaN          Race/Ethnicity
# 9656                  ...                         NaN          Race/Ethnicity
# 9657       5.9        ...                         6.8          Race/Ethnicity
# 9658       7.9        ...                         8.8          Race/Ethnicity
# 9678      13.3        ...                        13.9          Race/Ethnicity
# 9679                  ...                         NaN          Race/Ethnicity
# 9680                  ...                         NaN          Race/Ethnicity
# 9681       4.8        ...                         5.6          Race/Ethnicity
# 9682       7.4        ...                         8.2          Race/Ethnicity
# 9702      15.1        ...                        15.8          Race/Ethnicity
# 9703                  ...                         NaN          Race/Ethnicity
# 9704                  ...                         NaN          Race/Ethnicity
# 9705       5.3        ...                         6.1          Race/Ethnicity
# 9706       8.0        ...                         8.8          Race/Ethnicity
#
#                        Stratification1  \
# 9606               White, non-Hispanic
# 9607         Asian or Pacific Islander
# 9608  American Indian or Alaska Native
# 9609               Black, non-Hispanic
# 9610                          Hispanic
# 9630               White, non-Hispanic
# 9631         Asian or Pacific Islander
# 9632  American Indian or Alaska Native
# 9633               Black, non-Hispanic
# 9634                          Hispanic
# 9654               White, non-Hispanic
# 9655         Asian or Pacific Islander
# 9656  American Indian or Alaska Native
# 9657               Black, non-Hispanic
# 9658                          Hispanic
# 9678               White, non-Hispanic
# 9679         Asian or Pacific Islander
# 9680  American Indian or Alaska Native
# 9681               Black, non-Hispanic
# 9682                          Hispanic
# 9702               White, non-Hispanic
# 9703         Asian or Pacific Islander
# 9704  American Indian or Alaska Native
# 9705               Black, non-Hispanic
# 9706                          Hispanic
#
#                                    GeoLocation  LocationID TopicID QuestionID  \
# 9606  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9607  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9608  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9609  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9610  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9630  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9631  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9632  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9633  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9634  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9654  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9655  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9656  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9657  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9658  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9678  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9679  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9680  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9681  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9682  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9702  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9703  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9704  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9705  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
# 9706  (28.932040377000476, -81.92896053899966)          12     ALC     ALC6_0
#
#      DataValueTypeID  StratificationCategoryID1 StratificationID1
# 9606      AgeAdjRate                       RACE               WHT
# 9607      AgeAdjRate                       RACE               API
# 9608      AgeAdjRate                       RACE              AIAN
# 9609      AgeAdjRate                       RACE               BLK
# 9610      AgeAdjRate                       RACE               HIS
# 9630      AgeAdjRate                       RACE               WHT
# 9631      AgeAdjRate                       RACE               API
# 9632      AgeAdjRate                       RACE              AIAN
# 9633      AgeAdjRate                       RACE               BLK
# 9634      AgeAdjRate                       RACE               HIS
# 9654      AgeAdjRate                       RACE               WHT
# 9655      AgeAdjRate                       RACE               API
# 9656      AgeAdjRate                       RACE              AIAN
# 9657      AgeAdjRate                       RACE               BLK
# 9658      AgeAdjRate                       RACE               HIS
# 9678      AgeAdjRate                       RACE               WHT
# 9679      AgeAdjRate                       RACE               API
# 9680      AgeAdjRate                       RACE              AIAN
# 9681      AgeAdjRate                       RACE               BLK
# 9682      AgeAdjRate                       RACE               HIS
# 9702      AgeAdjRate                       RACE               WHT
# 9703      AgeAdjRate                       RACE               API
# 9704      AgeAdjRate                       RACE              AIAN
# 9705      AgeAdjRate                       RACE               BLK
# 9706      AgeAdjRate                       RACE               HIS
#
# [25 rows x 24 columns]

# %% [markdown]
# ### Explicit exploration of 2D frequency tables

# %% [markdown]
# Earlier we looked at a 2D table that showed the values of "Question" against "LocationAbbr", to see whether the distribution of questions was relatively even across all states.
#
# Let's take a deeper look at 2D frequency tables.
#
# **Question:** Why would you want to generate a 2D frequency table?
#
# **Question:** Why am I using pd.crosstab() instead of data.crosstab() in the example below?

# %%
pd.crosstab(data['LocationAbbr'], data['Topic'])
# Out:
# Topic         Alcohol  Arthritis  Asthma  Cancer  Cardiovascular Disease  \
# LocationAbbr
# AK                281        230     310      76                     776
# AL                281        230     310      76                     776
# AR                281        230     310      76                     776
# AZ                281        230     325      76                     776
# CA                281        230     310      76                     776
# CO                281        230     310      76                     776
# CT                281        230     310      76                     776
# DC                281        230     310      76                     776
# DE                281        230     310      76                     776
# FL                281        230     325      76                     777
# GA                281        230     310      76                     776
# GU                161        230     172      76                     167
# HI                281        230     310      76                     776
# IA                281        230     325      76                     776
# ID                281        230     310      76                     776
# IL                281        230     310      76                     776
# IN                281        230     310      76                     776
# KS                281        230     310      76                     776
# KY                281        230     325      76                     776
# LA                281        230     310      76                     776
# MA                281        230     310      76                     776
# MD                281        230     310      76                     776
# ME                281        230     310      76                     776
# MI                281        230     310      76                     776
# MN                281        230     310      76                     776
# MO                281        230     310      76                     776
# MS                281        230     310      76                     776
# MT                281        230     310      76                     776
# NC                281        230     325      76                     776
# ND                281        230     310      76                     776
# NE                281        230     325      76                     776
# NH                281        230     310      76                     776
# NJ                281        230     325      76                     776
# NM                281        230     310      76                     776
# NV                281        230     325      76                     776
# NY                281        230     325      76                     776
# OH                281        230     310      76                     776
# OK                281        230     310      76                     776
# OR                281        230     310      76                     776
# PA                281        230     310      76                     776
# PR                161        230     172      76                     167
# RI                281        230     310      76                     776
# SC                281        230     325      76                     776
# SD                281        230     310      76                     776
# TN                281        230     310      76                     776
# TX                281        230     310      76                     776
# US                 76         90      86      16                     146
# UT                281        230     310      76                     776
# VA                281        230     310      76                     776
# VI                161        230     172      76                     167
# VT                281        230     325      76                     776
# WA                281        230     310      76                     776
# WI                281        230     325      76                     776
# WV                281        230     310      76                     776
# WY                281        230     310      76                     776
#
# Topic         Chronic Kidney Disease  Chronic Obstructive Pulmonary Disease  \
# LocationAbbr
# AK                               152                                    514
# AL                               152                                    514
# AR                               152                                    514
# AZ                               152                                    514
# CA                               152                                    514
# CO                               152                                    514
# CT                               152                                    514
# DC                               152                                    514
# DE                               152                                    514
# FL                               152                                    514
# GA                               152                                    514
# GU                                32                                    256
# HI                               152                                    514
# IA                               152                                    514
# ID                               152                                    514
# IL                               152                                    514
# IN                               152                                    514
# KS                               152                                    514
# KY                               152                                    514
# LA                               152                                    514
# MA                               152                                    514
# MD                               152                                    514
# ME                               152                                    514
# MI                               152                                    514
# MN                               152                                    514
# MO                               152                                    514
# MS                               152                                    514
# MT                               152                                    514
# NC                               152                                    514
# ND                               152                                    514
# NE                               152                                    514
# NH                               152                                    514
# NJ                               152                                    514
# NM                               152                                    514
# NV                               152                                    514
# NY                               152                                    514
# OH                               152                                    514
# OK                               152                                    514
# OR                               152                                    514
# PA                               152                                    514
# PR                                32                                    256
# RI                               152                                    514
# SC                               152                                    514
# SD                               152                                    514
# TN                               152                                    514
# TX                               152                                    514
# US                                27                                    144
# UT                               152                                    514
# VA                               152                                    514
# VI                                32                                    256
# VT                               152                                    514
# WA                               152                                    514
# WI                               152                                    514
# WV                               152                                    514
# WY                               152                                    514
#
# Topic         Diabetes  Immunization  Mental Health
# LocationAbbr
# AK                 626             0             45
# AL                 626             0             45
# AR                 626             0             45
# AZ                 626             0             45
# CA                 626             0             45
# CO                 626             0             45
# CT                 626             0             45
# DC                 626             0             45
# DE                 626             0             45
# FL                 626             0             45
# GA                 626             0             45
# GU                 385             0             45
# HI                 626             0             45
# IA                 626             0             45
# ID                 626             0             45
# IL                 626             0             45
# IN                 626            32             45
# KS                 626            32             45
# KY                 626            32             45
# LA                 626            32             45
# MA                 626            32             45
# MD                 626            32             45
# ME                 626            32             45
# MI                 626            32             45
# MN                 626            32             45
# MO                 626            32             45
# MS                 626            32             45
# MT                 626            32             45
# NC                 626            32             45
# ND                 626            32             45
# NE                 626            32             45
# NH                 626            32             45
# NJ                 626            32             45
# NM                 626            32             45
# NV                 626            32             45
# NY                 626            32             45
# OH                 626            32             45
# OK                 626            32             45
# OR                 626            32             45
# PA                 626            32             45
# PR                 385            32             45
# RI                 626            32             45
# SC                 626            32             45
# SD                 626            32             45
# TN                 626            32             45
# TX                 626            32             45
# US                 176            12             15
# UT                 626            32             45
# VA                 626            32             45
# VI                 385            32             45
# VT                 626            32             45
# WA                 626            32             45
# WI                 626            32             45
# WV                 626            32             45
# WY                 626            32             45

# %% [markdown]
# ###  Histograms and barplots

# %% [markdown]
# **Question:** What is the difference between histograms and barplots?
#
# Look through the documentation for the Visualization functionality provided in pandas. What are some plotting functions that are available to you?

# %%
plt.style.use('ggplot') # Look up Hadley Wickham. Do it!

# First let's select a meaningful subset of the data
# Filter for the topic of Alcohol, and for the question Alcohol use among youth
alcohol_youth = data[data['Topic'].isin(['Alcohol']) &
                  data['Question'].isin(['Alcohol use among youth'])
                 ]

# Let's try to plot the DataValues for the questions in the topic 'Alcohol'
alcohol_youth.DataValue.plot(kind = 'bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-e54405e1946c> in <module>()
#       8
#       9 # Let's try to plot the DataValues for the questions in the topic 'Alcohol'
# ---> 10 alcohol_fl.DataValue.plot(kind = 'bar')
#      11 plt.show()
#
# /Users/Athena/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3598                            colormap=colormap, table=table, yerr=yerr,
#    3599                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3600                            **kwds)
#    3601     __call__.__doc__ = plot_series.__doc__
#    3602
#
# /Users/Athena/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2672                  yerr=yerr, xerr=xerr,
#    2673                  label=label, secondary_y=secondary_y,
# -> 2674                  **kwds)
#    2675
#    2676
#
# /Users/Athena/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /Users/Athena/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#    1039     def generate(self):
#    1040         self._args_adjust()
# -> 1041         self._compute_plot_data()
#    1042         self._setup_subplots()
#    1043         self._make_plot()
#
# /Users/Athena/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#    1148         if is_empty:
#    1149             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1150                             'plot'.format(numeric_data.__class__.__name__))
#    1151
#    1152         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %% [markdown]
# **Question:** Why doesn't the above work? How can we get a clue?
#
# **Exercise:** Come up with an expression that would help you figure out the source of the error.

# %% [markdown]
# **Exercise continued:** And in the cell below, solve the problem so that you will no longer get the error. There are many ways to do this.
#
# **Note:** Our dataset is small enough that it doesn't really make a difference which way you choose, but if it were bigger, you'd want to think through the pros and cons of each way that you can come up with, with respect to how much memory and time they'll consume.

# %% [markdown]
# Okay, now let's try the plot again.
#
# **Exercise:** Write the code that should produce the plot in the box below. Use the documentation to tidy it up. Hint: look for a way to make it horizontal, name the axes, and add the error bars from the relevant columns in the alcohol_youth dataframe.

# %% [markdown]
# **Exercise:** Now make a dodged barplot of the age-adjusted prevalence for each Race/Ethnicity, for the state of Florida. The dodged bars should represent the years, such that 2010-2014 are grouped together for each Race/Ethnicity.

# %% [markdown]
# ### More descriptive plots

# %% [markdown]
# **Boxplots** are useful for exploring relationships between a continuous variable and a categorical variable.
# You can add a scatter of the variable values behind the boxplot to provide an idea of the distribution.
#
# If you have lots of values, **violin plots** are a better option for displaying the distribution. They are a variation of boxplots that also show the distribution of the continuous variable as a histogram displayed vertically.
#
# **Scatterplots** are useful for exploring relationships between two continuous variables.

# %% [markdown]
# ## Missing data
#
# In your exploratory analysis phase, you'll also want to know how much missing data you have, which variables have the most missing data, and if there are any other patterns to the missingness.
#
# If there are **systematic patterns to the missingness, it could indicate that something went wrong somewhere**, and you'll have to do some digging to find out what that is. This is very important, as it will impact any conclusions or generalizations you try to make based on the data.
#
# **Exercise:** In the cell below write an expression that will return a count of how many values are missing for each variable in the original dataframe.

# %%
data.isnull().sum()
# Out:
# YearStart                        0
# YearEnd                          0
# LocationAbbr                     0
# LocationDesc                     0
# DataSource                       0
# Topic                            0
# Question                         0
# DataValueUnit                25488
# DataValueType                    0
# DataValue                    34911
# DataValueAlt                 55235
# DataValueFootnoteSymbol      56610
# DatavalueFootnote            56775
# LowConfidenceLimit           73497
# HighConfidenceLimit          73497
# StratificationCategory1          0
# Stratification1                  0
# GeoLocation                    788
# LocationID                       0
# TopicID                          0
# QuestionID                       0
# DataValueTypeID                  0
# StratificationCategoryID1        0
# StratificationID1                0
# dtype: int64

# %% [markdown]
# Does this seem correct?
#
# We saw earlier that some cells in DataValue were blank, while in HighConfidenceLimit they had NaN, indicating that the value is missing.
#
# If missingness claculated with the dataframe method isnull() relies on NaN values, it may have miscalculated those that are just empty.
#
# **The empty string is not the same thing as the null value.**
#
# If those variables are important for your analysis, you may need to explicitly force the empty strings to be replaced with NaN. There are lots of ways to do this. You can create new variables, a whole new dataframe, or simply figure out which option for read_csv() can handle missing values. You may be able to pass a list of strings that should be treated as missing values to that parameter (so that "" and "NaN" are read in as null), so that when the data is read in, this is taken care of.

# %% [markdown]
# ## Sources of bias in the data

# %% [markdown]
# Hopefully by now you're starting to get a sense of how exploratory analyses can feed into creating your QC pipeline.
#
# It is very, very important to **be careful when applying QC measures so that you don't generate bias** in your dataset!
#
# **Question:** What is bias? Can you think of a scenario under which you have introduced bias through a QC filter?
#
# **Question:** What may be other sources of bias?

# %% [markdown]
# ## Organizing your pipelines and notebooks

# %% [markdown]
# Once you have streamlined your quality control process, and you feel like you understand what is in the data, you can exit the loop and put together a pipeline that takes the dataset through quality control linearly.
#
# At that point it would make sense to split that into a different notebook than your lab/development notebook. You should still be using Markdown or comments or some other way to describe what you are doing at each step of your QC pipeline, but it won't necessarily be clear in that report alone how you came across a problem in the data which you're addressing with each of the quality control steps. You can give a high-level description of the kind "In the exploratory analysis I noticed X, which led to the development of the QC filter Y using the value M as the filtering threshold."

# %% [markdown]
# ## When should I export a manipulated dataset as a new file?

# %% [markdown]
# First of all, let's be clear that your manipulated dataset should be saved separately from your original data! Separate directories, labelled descriptively.
#
# At any point in the process, you can export your dataset, for example by writing a manipulated DataFrame back into a new .csv. It is up to you to choose when it is appropriate to do that. Try to minimize the number of "slightly different" copies that you have of the same dataset. You'll have the scripts that manipulate the dataset to put it into its final form, and which make your analysis reproducible, so it's less important to have the intermediate datasets saved than it is to save your scripts, complete with plenty of comments and designed modularly.
#
# Consider things like the storage space that it would take to save multiple forms of a dataset, the confusion that it could generate to not know off hand what are the differences between the various forms of the dataset, against the benefit of not having to wait for the dataset to be processed again.
#
# It's already becoming evident from this discussion that I am having with myself that for most pipelines you'll want the final form of the manipulated, pre-processed, clean data to be the only copy that you have stored, other than the original data. Never over-write the original data.

# %% [markdown]
# ## Next steps

# %% [markdown]
# Tomorrow, we will continue exploring the CDI dataset, and perform some basic tests to assess relationships between variables.
